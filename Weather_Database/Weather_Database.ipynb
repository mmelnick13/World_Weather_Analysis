# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ae9e6194030296d5fb47be54eee110a9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | sabang
# Processing Record 3 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | mecca
# Processing Record 19 of Set 1 | sao gabriel da cachoeira
# Processing Record 20 of Set 1 | maldonado
# Processing Record 21 of Set 1 | conde
# Processing Record 22 of Set 1 | shepsi
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | saint-augustin
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | talnakh
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | uige
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | kudahuvadhoo
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | meulaboh
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | mount gambier
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | polunochnoye
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | mnogovershinnyy
# Processing Record 44 of Set 1 | pangnirtung
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | zverinogolovskoye
# Processing Record 47 of Set 1 | abha
# Processing Record 48 of Set 1 | hovd
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | grindavik
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 2 | santa cruz de la palma
# Processing Record 3 of Set 2 | ixtapa
# Processing Record 4 of Set 2 | camacha
# Processing Record 5 of Set 2 | tubuala
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | kruisfontein
# Processing Record 10 of Set 2 | tashtyp
# Processing Record 11 of Set 2 | leh
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | stornoway
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 2 | alexandria
# Processing Record 18 of Set 2 | grand baie
# Processing Record 19 of Set 2 | provost
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | bonthe
# Processing Record 25 of Set 2 | westport
# Processing Record 26 of Set 2 | valdivia
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | krasnoselkup
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | lumby
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | bamako
# Processing Record 34 of Set 2 | puerto el triunfo
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | kisangani
# Processing Record 39 of Set 2 | ust-kut
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | sobolevo
# Processing Record 42 of Set 2 | tangier
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | burnie
# Processing Record 45 of Set 2 | itaituba
# Processing Record 46 of Set 2 | jega
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | ceuta
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | ihosy
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | bundaberg
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | kapit
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 3 | parker
# Processing Record 10 of Set 3 | badiraguato
# Processing Record 11 of Set 3 | brigantine
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | istisu
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | kununurra
# Processing Record 17 of Set 3 | kolondieba
# Processing Record 18 of Set 3 | arman
# Processing Record 19 of Set 3 | birin
# Processing Record 20 of Set 3 | hailar
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | pattaya
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | buala
# Processing Record 25 of Set 3 | bonavista
# Processing Record 26 of Set 3 | stanislav
# Processing Record 27 of Set 3 | lagos
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | wum
# Processing Record 31 of Set 3 | henties bay
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | albion
# Processing Record 34 of Set 3 | asau
# Processing Record 35 of Set 3 | dakar
# Processing Record 36 of Set 3 | pimentel
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | mount kisco
# Processing Record 39 of Set 3 | toktogul
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 43 of Set 3 | russell
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | merritt island
# Processing Record 46 of Set 3 | port moresby
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | pueblo nuevo
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | big spring
# Processing Record 1 of Set 4 | necochea
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | sanming
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | puerto escondido
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | sayyan
# Processing Record 8 of Set 4 | chalons-en-champagne
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | senno
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | ler
# Processing Record 13 of Set 4 | bridlington
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | panama city
# Processing Record 16 of Set 4 | hamilton
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | usinsk
# Processing Record 19 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 4 | north platte
# Processing Record 21 of Set 4 | toora-khem
# Processing Record 22 of Set 4 | osakarovka
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | faya
# Processing Record 25 of Set 4 | shimoda
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | whakatane
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | wageningen
# Processing Record 32 of Set 4 | waipawa
# Processing Record 33 of Set 4 | odemira
# Processing Record 34 of Set 4 | tocache
# Processing Record 35 of Set 4 | kailasahar
# City not found. Skipping...
# Processing Record 36 of Set 4 | aguimes
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | auki
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | mount isa
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | kutum
# Processing Record 44 of Set 4 | taoudenni
# Processing Record 45 of Set 4 | avera
# Processing Record 46 of Set 4 | birjand
# Processing Record 47 of Set 4 | uribia
# Processing Record 48 of Set 4 | padang
# Processing Record 49 of Set 4 | vinh
# Processing Record 50 of Set 4 | rio pardo de minas
# Processing Record 1 of Set 5 | voh
# Processing Record 2 of Set 5 | gorontalo
# Processing Record 3 of Set 5 | bijie
# Processing Record 4 of Set 5 | airai
# Processing Record 5 of Set 5 | solton
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | suntar
# Processing Record 8 of Set 5 | high level
# Processing Record 9 of Set 5 | ndele
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | san quintin
# Processing Record 12 of Set 5 | sinazongwe
# Processing Record 13 of Set 5 | makakilo city
# Processing Record 14 of Set 5 | chokurdakh
# Processing Record 15 of Set 5 | salisbury
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | alibag
# Processing Record 18 of Set 5 | kotelnikovo
# Processing Record 19 of Set 5 | yuzhnyy
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | karaton
# Processing Record 22 of Set 5 | svobodnyy
# Processing Record 23 of Set 5 | turukhansk
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | tilichiki
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | bubaque
# Processing Record 28 of Set 5 | port hedland
# Processing Record 29 of Set 5 | englewood
# Processing Record 30 of Set 5 | takoradi
# Processing Record 31 of Set 5 | kondopoga
# Processing Record 32 of Set 5 | ocampo
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | karlshamn
# Processing Record 35 of Set 5 | hwange
# Processing Record 36 of Set 5 | new norfolk
# Processing Record 37 of Set 5 | port-gentil
# Processing Record 38 of Set 5 | wajima
# Processing Record 39 of Set 5 | camacupa
# Processing Record 40 of Set 5 | namibe
# Processing Record 41 of Set 5 | guerrero negro
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 43 of Set 5 | tadine
# Processing Record 44 of Set 5 | kijang
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | sur
# Processing Record 47 of Set 5 | the valley
# Processing Record 48 of Set 5 | cristalina
# Processing Record 49 of Set 5 | aykhal
# Processing Record 50 of Set 5 | hasaki
# Processing Record 1 of Set 6 | kavaratti
# Processing Record 2 of Set 6 | vardo
# Processing Record 3 of Set 6 | zhireken
# Processing Record 4 of Set 6 | paamiut
# Processing Record 5 of Set 6 | nerchinskiy zavod
# Processing Record 6 of Set 6 | forbes
# Processing Record 7 of Set 6 | nipawin
# Processing Record 8 of Set 6 | garden city
# Processing Record 9 of Set 6 | vuktyl
# Processing Record 10 of Set 6 | tiksi
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | gamba
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | vila
# Processing Record 16 of Set 6 | jiaozuo
# Processing Record 17 of Set 6 | batemans bay
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | indian head
# Processing Record 20 of Set 6 | vanavara
# Processing Record 21 of Set 6 | belmonte
# Processing Record 22 of Set 6 | novobirilyussy
# Processing Record 23 of Set 6 | denpasar
# Processing Record 24 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | lac du bonnet
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | borgarnes
# Processing Record 29 of Set 6 | shirokiy
# Processing Record 30 of Set 6 | puerto leguizamo
# Processing Record 31 of Set 6 | marsa matruh
# Processing Record 32 of Set 6 | paranaiba
# Processing Record 33 of Set 6 | doka
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | comodoro rivadavia
# Processing Record 36 of Set 6 | griffith
# Processing Record 37 of Set 6 | beidao
# Processing Record 38 of Set 6 | cidreira
# Processing Record 39 of Set 6 | aragats
# Processing Record 40 of Set 6 | mayumba
# Processing Record 41 of Set 6 | paraiso
# Processing Record 42 of Set 6 | leshukonskoye
# Processing Record 43 of Set 6 | kavieng
# Processing Record 44 of Set 6 | chemax
# Processing Record 45 of Set 6 | la orilla
# Processing Record 46 of Set 6 | ambon
# Processing Record 47 of Set 6 | vostok
# Processing Record 48 of Set 6 | chara
# Processing Record 49 of Set 6 | jinchang
# Processing Record 50 of Set 6 | nova mayachka
# Processing Record 1 of Set 7 | palu
# Processing Record 2 of Set 7 | boyolangu
# Processing Record 3 of Set 7 | bheramara
# Processing Record 4 of Set 7 | kungurtug
# Processing Record 5 of Set 7 | kiskore
# Processing Record 6 of Set 7 | socorro
# Processing Record 7 of Set 7 | yatou
# Processing Record 8 of Set 7 | lincoln
# Processing Record 9 of Set 7 | udachnyy
# Processing Record 10 of Set 7 | seddon
# Processing Record 11 of Set 7 | nisia floresta
# Processing Record 12 of Set 7 | chilca
# Processing Record 13 of Set 7 | sooke
# Processing Record 14 of Set 7 | portlethen
# Processing Record 15 of Set 7 | east london
# Processing Record 16 of Set 7 | pouebo
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | manokwari
# Processing Record 19 of Set 7 | tairua
# Processing Record 20 of Set 7 | abu zabad
# Processing Record 21 of Set 7 | anamur
# Processing Record 22 of Set 7 | carnarvon
# Processing Record 23 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 24 of Set 7 | college
# Processing Record 25 of Set 7 | bayanday
# Processing Record 26 of Set 7 | tosya
# Processing Record 27 of Set 7 | jurbarkas
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | ovre ardal
# Processing Record 30 of Set 7 | pacific grove
# Processing Record 31 of Set 7 | waw
# Processing Record 32 of Set 7 | mahon
# Processing Record 33 of Set 7 | tokomaru
# Processing Record 34 of Set 7 | salamiyah
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | leiyang
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | matara
# Processing Record 39 of Set 7 | athabasca
# Processing Record 40 of Set 7 | porto walter
# Processing Record 41 of Set 7 | shelabolikha
# Processing Record 42 of Set 7 | alugan
# Processing Record 43 of Set 7 | acapulco
# Processing Record 44 of Set 7 | antalaha
# Processing Record 45 of Set 7 | tlyarota
# City not found. Skipping...
# Processing Record 46 of Set 7 | dicabisagan
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | baykit
# Processing Record 49 of Set 7 | alice springs
# Processing Record 50 of Set 7 | regina
# Processing Record 1 of Set 8 | pangai
# Processing Record 2 of Set 8 | catamarca
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | sovetskiy
# Processing Record 5 of Set 8 | muli
# Processing Record 6 of Set 8 | inuvik
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | derzhavinsk
# Processing Record 9 of Set 8 | lasa
# Processing Record 10 of Set 8 | torbay
# Processing Record 11 of Set 8 | dunmore town
# Processing Record 12 of Set 8 | yulara
# Processing Record 13 of Set 8 | lucea
# Processing Record 14 of Set 8 | maymyo
# Processing Record 15 of Set 8 | canon city
# Processing Record 16 of Set 8 | morwell
# Processing Record 17 of Set 8 | alofi
# Processing Record 18 of Set 8 | moroni
# Processing Record 19 of Set 8 | beloha
# Processing Record 20 of Set 8 | kaitangata
# Processing Record 21 of Set 8 | ponta delgada
# Processing Record 22 of Set 8 | kahului
# Processing Record 23 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 8 | xuddur
# Processing Record 25 of Set 8 | creston
# Processing Record 26 of Set 8 | danielskuil
# Processing Record 27 of Set 8 | qasigiannguit
# Processing Record 28 of Set 8 | fallon
# Processing Record 29 of Set 8 | tutoia
# Processing Record 30 of Set 8 | asyut
# Processing Record 31 of Set 8 | altay
# Processing Record 32 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set 8 | novopokrovka
# Processing Record 37 of Set 8 | nuuk
# Processing Record 38 of Set 8 | asfi
# Processing Record 39 of Set 8 | san vicente
# Processing Record 40 of Set 8 | talaya
# Processing Record 41 of Set 8 | awjilah
# Processing Record 42 of Set 8 | ust-omchug
# Processing Record 43 of Set 8 | bonnyville
# Processing Record 44 of Set 8 | mednogorsk
# Processing Record 45 of Set 8 | san joaquin
# Processing Record 46 of Set 8 | mgachi
# Processing Record 47 of Set 8 | manati
# Processing Record 48 of Set 8 | chuka
# Processing Record 49 of Set 8 | saint anthony
# Processing Record 50 of Set 8 | nanchong
# Processing Record 1 of Set 9 | tondano
# Processing Record 2 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 9 | lipin bor
# Processing Record 4 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 5 of Set 9 | maneromango
# Processing Record 6 of Set 9 | haines junction
# Processing Record 7 of Set 9 | flin flon
# Processing Record 8 of Set 9 | sidney
# Processing Record 9 of Set 9 | egvekinot
# Processing Record 10 of Set 9 | loding
# Processing Record 11 of Set 9 | gravdal
# Processing Record 12 of Set 9 | isangel
# Processing Record 13 of Set 9 | dandong
# Processing Record 14 of Set 9 | araouane
# Processing Record 15 of Set 9 | ust-nera
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 9 | the pas
# Processing Record 19 of Set 9 | deputatskiy
# Processing Record 20 of Set 9 | lethem
# Processing Record 21 of Set 9 | huambo
# Processing Record 22 of Set 9 | lae
# Processing Record 23 of Set 9 | tuatapere
# Processing Record 24 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 9 | poso
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | nacala
# Processing Record 28 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 9 | kaeo
# Processing Record 30 of Set 9 | keflavik
# Processing Record 31 of Set 9 | redmond
# Processing Record 32 of Set 9 | tulsipur
# Processing Record 33 of Set 9 | isla vista
# Processing Record 34 of Set 9 | mende
# Processing Record 35 of Set 9 | preobrazheniye
# Processing Record 36 of Set 9 | bathsheba
# Processing Record 37 of Set 9 | lapua
# Processing Record 38 of Set 9 | beyneu
# Processing Record 39 of Set 9 | port hueneme
# Processing Record 40 of Set 9 | rundu
# Processing Record 41 of Set 9 | talara
# Processing Record 42 of Set 9 | saskylakh
# Processing Record 43 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 9 | solnechnyy
# Processing Record 45 of Set 9 | charlestown
# Processing Record 46 of Set 9 | agadez
# Processing Record 47 of Set 9 | cururupu
# Processing Record 48 of Set 9 | brezno
# Processing Record 49 of Set 9 | seybaplaya
# Processing Record 50 of Set 9 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 1 of Set 10 | kamenka
# Processing Record 2 of Set 10 | orlik
# Processing Record 3 of Set 10 | ikare
# Processing Record 4 of Set 10 | zhoucheng
# Processing Record 5 of Set 10 | redlands
# Processing Record 6 of Set 10 | taldan
# Processing Record 7 of Set 10 | esmeraldas
# Processing Record 8 of Set 10 | mundo nuevo
# Processing Record 9 of Set 10 | tukrah
# Processing Record 10 of Set 10 | klaksvik
# Processing Record 11 of Set 10 | grafton
# Processing Record 12 of Set 10 | soto la marina
# Processing Record 13 of Set 10 | sambava
# Processing Record 14 of Set 10 | nkpor
# Processing Record 15 of Set 10 | malinyi
# Processing Record 16 of Set 10 | taraz
# Processing Record 17 of Set 10 | inhambane
# Processing Record 18 of Set 10 | la asuncion
# Processing Record 19 of Set 10 | jijiga
# Processing Record 20 of Set 10 | imelda
# Processing Record 21 of Set 10 | tautira
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | majene
# Processing Record 24 of Set 10 | sao jose da coroa grande
# Processing Record 25 of Set 10 | los llanos de aridane
# Processing Record 26 of Set 10 | novaya igirma
# Processing Record 27 of Set 10 | chernyshevsk
# Processing Record 28 of Set 10 | oak harbor
# Processing Record 29 of Set 10 | sergeyevka
# Processing Record 30 of Set 10 | sioux lookout
# Processing Record 31 of Set 10 | catuday
# Processing Record 32 of Set 10 | owando
# Processing Record 33 of Set 10 | san blas
# Processing Record 34 of Set 10 | nago
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | taltal
# Processing Record 37 of Set 10 | phalaborwa
# Processing Record 38 of Set 10 | yakeshi
# Processing Record 39 of Set 10 | gizo
# Processing Record 40 of Set 10 | sola
# Processing Record 41 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 10 | chapais
# Processing Record 43 of Set 10 | broken hill
# Processing Record 44 of Set 10 | misratah
# Processing Record 45 of Set 10 | igarka
# Processing Record 46 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 10 | barentu
# Processing Record 48 of Set 10 | coos bay
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | mahina
# Processing Record 1 of Set 11 | zhucheng
# Processing Record 2 of Set 11 | margate
# Processing Record 3 of Set 11 | coahuayana
# Processing Record 4 of Set 11 | kushmurun
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | ulaanbaatar
# Processing Record 7 of Set 11 | isabela
# Processing Record 8 of Set 11 | lucapa
# Processing Record 9 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 11 | ostrovnoy
# Processing Record 11 of Set 11 | buraydah
# Processing Record 12 of Set 11 | prokuplje
# Processing Record 13 of Set 11 | ambilobe
# Processing Record 14 of Set 11 | samarai
# Processing Record 15 of Set 11 | rocha
# Processing Record 16 of Set 11 | hachinohe
# Processing Record 17 of Set 11 | portland
# Processing Record 18 of Set 11 | wattegama
# Processing Record 19 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | ankazoabo
# Processing Record 21 of Set 11 | juba
# Processing Record 22 of Set 11 | clonakilty
# Processing Record 23 of Set 11 | hualmay
# Processing Record 24 of Set 11 | ibra
# Processing Record 25 of Set 11 | show low
# Processing Record 26 of Set 11 | gwadar
# Processing Record 27 of Set 11 | lanzhou
# Processing Record 28 of Set 11 | nador
# Processing Record 29 of Set 11 | manacor
# Processing Record 30 of Set 11 | farmington
# Processing Record 31 of Set 11 | krasnyy luch
# Processing Record 32 of Set 11 | neuquen
# Processing Record 33 of Set 11 | lazaro cardenas
# Processing Record 34 of Set 11 | jutai
# Processing Record 35 of Set 11 | swinoujscie
# Processing Record 36 of Set 11 | balabac
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | vicam
# Processing Record 39 of Set 11 | richards bay
# Processing Record 40 of Set 11 | poum
# Processing Record 41 of Set 11 | monrovia
# Processing Record 42 of Set 11 | roebourne
# Processing Record 43 of Set 11 | bang mun nak
# Processing Record 44 of Set 11 | turayf
# Processing Record 45 of Set 11 | linjiang
# Processing Record 46 of Set 11 | benjamin constant
# Processing Record 47 of Set 11 | bowen
# Processing Record 48 of Set 11 | phek
# Processing Record 49 of Set 11 | salym
# Processing Record 50 of Set 11 | shieli
# Processing Record 1 of Set 12 | marsabit
# Processing Record 2 of Set 12 | chimoio
# Processing Record 3 of Set 12 | coventry
# Processing Record 4 of Set 12 | sembakung
# Processing Record 5 of Set 12 | nyurba
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | otavi
# Processing Record 8 of Set 12 | dubbo
# Processing Record 9 of Set 12 | akonolinga
# Processing Record 10 of Set 12 | alta floresta
# Processing Record 11 of Set 12 | craigieburn
# Processing Record 12 of Set 12 | barpeta
# Processing Record 13 of Set 12 | khovu-aksy
# Processing Record 14 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 15 of Set 12 | ilulissat
# Processing Record 16 of Set 12 | maltahohe
# Processing Record 17 of Set 12 | briancon
# Processing Record 18 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 12 | zainsk
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | yarensk
# Processing Record 22 of Set 12 | fukue
# Processing Record 23 of Set 12 | samfya
# Processing Record 24 of Set 12 | camana
# Processing Record 25 of Set 12 | port shepstone
# Processing Record 26 of Set 12 | valparaiso
# Processing Record 27 of Set 12 | baiao
# Processing Record 28 of Set 12 | gaoua
# Processing Record 29 of Set 12 | ekpoma
# Processing Record 30 of Set 12 | wichita falls
# Processing Record 31 of Set 12 | khandyga
# Processing Record 32 of Set 12 | lagoa
# Processing Record 33 of Set 12 | sokolo
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | maceio
# Processing Record 36 of Set 12 | olafsvik
# Processing Record 37 of Set 12 | batagay-alyta
# Processing Record 38 of Set 12 | tselinnoye
# Processing Record 39 of Set 12 | joao pinheiro
# Processing Record 40 of Set 12 | rohru
# Processing Record 41 of Set 12 | markova
# Processing Record 42 of Set 12 | basavakalyan
# Processing Record 43 of Set 12 | santa fe
# Processing Record 44 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 12 | san jeronimo
# Processing Record 46 of Set 12 | mehamn
# Processing Record 47 of Set 12 | nova olinda do norte
# Processing Record 48 of Set 12 | bacungan
# Processing Record 49 of Set 12 | renqiu
# Processing Record 50 of Set 12 | bereda
# Processing Record 1 of Set 13 | te anau
# Processing Record 2 of Set 13 | shangrao
# Processing Record 3 of Set 13 | ancud
# Processing Record 4 of Set 13 | santarem
# Processing Record 5 of Set 13 | katangli
# Processing Record 6 of Set 13 | mitsamiouli
# Processing Record 7 of Set 13 | hohhot
# Processing Record 8 of Set 13 | tucurui
# Processing Record 9 of Set 13 | namatanai
# Processing Record 10 of Set 13 | setermoen
# Processing Record 11 of Set 13 | inirida
# Processing Record 12 of Set 13 | ulaangom
# Processing Record 13 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 14 of Set 13 | campo maior
# Processing Record 15 of Set 13 | parfenyevo
# Processing Record 16 of Set 13 | ayan
# Processing Record 17 of Set 13 | sao pedro do piaui
# Processing Record 18 of Set 13 | semey
# Processing Record 19 of Set 13 | bam
# Processing Record 20 of Set 13 | isiro
# Processing Record 21 of Set 13 | cine
# Processing Record 22 of Set 13 | bontang
# Processing Record 23 of Set 13 | luderitz
# Processing Record 24 of Set 13 | potam
# Processing Record 25 of Set 13 | kattivakkam
# Processing Record 26 of Set 13 | tura
# Processing Record 27 of Set 13 | lesnoy
# Processing Record 28 of Set 13 | inta
# Processing Record 29 of Set 13 | saldanha
# Processing Record 30 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 31 of Set 13 | den helder
# Processing Record 32 of Set 13 | belaya kholunitsa
# Processing Record 33 of Set 13 | chachapoyas
# Processing Record 34 of Set 13 | puro
# Processing Record 35 of Set 13 | itarema
# Processing Record 36 of Set 13 | saint marys
# Processing Record 37 of Set 13 | seda
# Processing Record 38 of Set 13 | naranjito
# Processing Record 39 of Set 13 | jiaxing
# Processing Record 40 of Set 13 | anaconda
# Processing Record 41 of Set 13 | labuhan
# Processing Record 42 of Set 13 | whitehorse
# Processing Record 43 of Set 13 | dryden
# Processing Record 44 of Set 13 | mwanza
# Processing Record 45 of Set 13 | yurya
# City not found. Skipping...
# Processing Record 46 of Set 13 | soyo
# Processing Record 47 of Set 13 | mbeya
# Processing Record 48 of Set 13 | chubbuck
# Processing Record 49 of Set 13 | taksimo
# Processing Record 50 of Set 13 | verkhnyaya toyma
# Processing Record 1 of Set 14 | bulaevo
# Processing Record 2 of Set 14 | tomigusuku
# Processing Record 3 of Set 14 | mitu
# Processing Record 4 of Set 14 | tumut
# Processing Record 5 of Set 14 | juneau
# Processing Record 6 of Set 14 | hillsborough
# Processing Record 7 of Set 14 | okakarara
# Processing Record 8 of Set 14 | port hardy
# City not found. Skipping...
# Processing Record 9 of Set 14 | kiunga
# City not found. Skipping...
# Processing Record 10 of Set 14 | salinopolis
# City not found. Skipping...
# Processing Record 11 of Set 14 | corrente
# City not found. Skipping...
# Processing Record 12 of Set 14 | hervey bay
# City not found. Skipping...
# Processing Record 13 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 14 | banda aceh
# City not found. Skipping...
# Processing Record 15 of Set 14 | hendersonville
# City not found. Skipping...
# Processing Record 16 of Set 14 | quatre cocos
# City not found. Skipping...
# Processing Record 17 of Set 14 | japura
# City not found. Skipping...
# Processing Record 18 of Set 14 | samana
# City not found. Skipping...
# Processing Record 19 of Set 14 | urambo
# City not found. Skipping...
# Processing Record 20 of Set 14 | skibbereen
# City not found. Skipping...
# Processing Record 21 of Set 14 | grand gaube
# City not found. Skipping...
# Processing Record 22 of Set 14 | cayenne
# City not found. Skipping...
# Processing Record 23 of Set 14 | nantucket
# City not found. Skipping...
# Processing Record 24 of Set 14 | marzuq
# City not found. Skipping...
# Processing Record 25 of Set 14 | invermere
# City not found. Skipping...
# Processing Record 26 of Set 14 | havoysund
# City not found. Skipping...
# Processing Record 27 of Set 14 | wonthaggi
# City not found. Skipping...
# Processing Record 28 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 29 of Set 14 | kunming
# City not found. Skipping...
# Processing Record 30 of Set 14 | sines
# City not found. Skipping...
# Processing Record 31 of Set 14 | tabou
# City not found. Skipping...
# Processing Record 32 of Set 14 | pundaguitan
# City not found. Skipping...
# Processing Record 33 of Set 14 | harper
# City not found. Skipping...
# Processing Record 34 of Set 14 | yanam
# City not found. Skipping...
# Processing Record 35 of Set 14 | alyangula
# City not found. Skipping...
# Processing Record 36 of Set 14 | baherden
# City not found. Skipping...
# Processing Record 37 of Set 14 | cartagena del chaira
# City not found. Skipping...
# Processing Record 38 of Set 14 | porbandar
# City not found. Skipping...
# Processing Record 39 of Set 14 | bardiyah
# City not found. Skipping...
# Processing Record 40 of Set 14 | balaipungut
# City not found. Skipping...
# Processing Record 41 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 14 | sisimiut
# City not found. Skipping...
# Processing Record 43 of Set 14 | stokmarknes
# City not found. Skipping...
# Processing Record 44 of Set 14 | agnibilekrou
# City not found. Skipping...
# Processing Record 45 of Set 14 | champerico
# City not found. Skipping...
# Processing Record 46 of Set 14 | kinshasa
# City not found. Skipping...
# Processing Record 47 of Set 14 | manicore
# City not found. Skipping...
# Processing Record 48 of Set 14 | atka
# City not found. Skipping...
# Processing Record 49 of Set 14 | aksarka
# City not found. Skipping...
# Processing Record 50 of Set 14 | lao cai
# City not found. Skipping...
# Processing Record 1 of Set 15 | ajaccio
# City not found. Skipping...
# Processing Record 2 of Set 15 | nouakchott
# City not found. Skipping...
# Processing Record 3 of Set 15 | tazovskiy
# City not found. Skipping...
# Processing Record 4 of Set 15 | river falls
# City not found. Skipping...
# Processing Record 5 of Set 15 | aswan
# City not found. Skipping...
# Processing Record 6 of Set 15 | escondido
# City not found. Skipping...
# Processing Record 7 of Set 15 | komsomolskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | saint-pierre
# City not found. Skipping...
# Processing Record 9 of Set 15 | okato
# City not found. Skipping...
# Processing Record 10 of Set 15 | ust-kuyga
# City not found. Skipping...
# Processing Record 11 of Set 15 | xihe
# City not found. Skipping...
# Processing Record 12 of Set 15 | maamba
# City not found. Skipping...
# Processing Record 13 of Set 15 | amos
# City not found. Skipping...
# Processing Record 14 of Set 15 | walvis bay
# City not found. Skipping...
# Processing Record 15 of Set 15 | kearney
# City not found. Skipping...
# Processing Record 16 of Set 15 | iquitos
# City not found. Skipping...
# Processing Record 17 of Set 15 | oranjemund
# City not found. Skipping...
# Processing Record 18 of Set 15 | saint-jean-de-braye
# City not found. Skipping...
# Processing Record 19 of Set 15 | tartagal
# City not found. Skipping...
# Processing Record 20 of Set 15 | katobu
# City not found. Skipping...
# Processing Record 21 of Set 15 | jiexiu
# City not found. Skipping...
# Processing Record 22 of Set 15 | jimani
# City not found. Skipping...
# Processing Record 23 of Set 15 | okhotsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | chifeng
# City not found. Skipping...
# Processing Record 25 of Set 15 | sao francisco do sul
# City not found. Skipping...
# Processing Record 26 of Set 15 | lawrenceburg
# City not found. Skipping...
# Processing Record 27 of Set 15 | raga
# City not found. Skipping...
# Processing Record 28 of Set 15 | plyussa
# City not found. Skipping...
# Processing Record 29 of Set 15 | savona
# City not found. Skipping...
# Processing Record 30 of Set 15 | ayr
# City not found. Skipping...
# Processing Record 31 of Set 15 | anlu
# City not found. Skipping...
# Processing Record 32 of Set 15 | sangmelima
# City not found. Skipping...
# Processing Record 33 of Set 15 | zabid
# City not found. Skipping...
# Processing Record 34 of Set 15 | ulladulla
# City not found. Skipping...
# Processing Record 35 of Set 15 | malatya
# City not found. Skipping...
# Processing Record 36 of Set 15 | pasni
# City not found. Skipping...
# Processing Record 37 of Set 15 | businga
# City not found. Skipping...
# Processing Record 38 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 15 | marsh harbour
# City not found. Skipping...
# Processing Record 41 of Set 15 | dakoro
# City not found. Skipping...
# Processing Record 42 of Set 15 | careiro da varzea
# City not found. Skipping...
# Processing Record 43 of Set 15 | kohtla-jarve
# City not found. Skipping...
# Processing Record 44 of Set 15 | nizwa
# City not found. Skipping...
# Processing Record 45 of Set 15 | loiza
# City not found. Skipping...
# Processing Record 46 of Set 15 | grand centre
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 612

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     56.08        79          21
# 1        Sabang      ID   5.8933   95.3214     83.12        74         100
# 2       Qaanaaq      GL  77.4840  -69.3632     38.07        84         100
# 3   Port Alfred      ZA -33.5906   26.8910     60.91        83           0
# 4  Punta Arenas      CL -53.1500  -70.9167     39.31        87          20
# 5   Yellowknife      CA  62.4560 -114.3525     63.28        59          75
# 6        Laguna      US  38.4210 -121.4238     89.44        50           1
# 7       Fortuna      US  40.5982 -124.1573     69.42        70          75
# 8       Rikitea      PF -23.1203 -134.9692     75.63        79         100
# 9        Dingle      PH  10.9995  122.6711     76.30        92          52
#
#    Wind Speed Current Description
# 0       12.35          light rain
# 1       15.97     overcast clouds
# 2        5.08     overcast clouds
# 3       15.19           clear sky
# 4        7.56          few clouds
# 5        4.61       broken clouds
# 6        1.99           clear sky
# 7        8.01       broken clouds
# 8       12.06     overcast clouds
# 9        2.33          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
